# %% [markdown]
# <a href="https://colab.research.google.com/github/Redwoods/Arduino/blob/master/ar-iot/py-pandas/iot_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pandas: Loading the remote csv file
#
# > [Pandas: Tutorial-reas_csv()](https://www.marsja.se/pandas-read-csv-tutorial-to-csv/amp/)
# ---
# > [파이썬 모듈 - pandas 기초 (by Redwoods)](https://github.com/Redwoods/Lec/blob/master/simulation/code/py_modules/py_module_3_pandas.ipynb)

# %% [markdown]
# ---

# %%
import pandas as pd

# %%
# Access a data file in csv format from the remote express server with CORS.
url="http://life21c.inje.ac.kr:3030/data/ppg5k.csv"  # CORS powered express server!
c=pd.read_csv(url, index_col='Time')

# %%
c.shape
# Out:
# (5000, 1)

# %%
c.head()
# Out:
#                        PPG
# Time
# 2015-07-24 12:43:00.7  444
# 2015-07-24 12:43:00.8  425
# 2015-07-24 12:43:00.8  423
# 2015-07-24 12:43:00.9  415
# 2015-07-24 12:43:00.9  406

# %%
c.tail()
# Out:
#                        PPG
# Time
# 2015-07-24 12:47:12.1  364
# 2015-07-24 12:47:12.1  380
# 2015-07-24 12:47:12.1  386
# 2015-07-24 12:47:12.2  371
# 2015-07-24 12:47:12.3  354

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, 2015-07-24 12:43:00.7 to 2015-07-24 12:47:12.3
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PPG     5000 non-null   int64
# dtypes: int64(1)
# memory usage: 78.1+ KB

# %%
# another method to read csv
c2=pd.read_csv(url, index_col=0)
c2.head()
# Out:
#                        PPG
# Time
# 2015-07-24 12:43:00.7  444
# 2015-07-24 12:43:00.8  425
# 2015-07-24 12:43:00.8  423
# 2015-07-24 12:43:00.9  415
# 2015-07-24 12:43:00.9  406

# %% [markdown]
# ### 데이터 시각화
# - matplotlib module
# - pandas ploting

# %%
import matplotlib.pyplot as plt

# %%
c.plot(figsize=(12,5), color='r', title="PPG")
# Out:
# <Axes: title={'center': 'PPG'}, xlabel='Time'>

# %%
c[:1000].plot(figsize=(12,5), color='r', title="PPG")
# Out:
# <Axes: title={'center': 'PPG'}, xlabel='Time'>

# %% [markdown]
# ### iot data
# > Sensor data from Arduino with CdS and DHT22
#
# - temperature
# - humidity
# - luminosity

# %%
# Access a data file in csv format from the remote express server with CORS.
url="http://life21c.inje.ac.kr:3030/data/iot_chaos.csv"
iot=pd.read_csv(url, index_col='date')

# %%
iot.shape
# Out:
# (100000, 3)

# %%
iot.head()
# Out:
#                          temperature  humidity  luminosity
# date
# 2018-11-26 17:50:18.613         18.9      31.6          45
# 2018-11-26 17:50:08.353         18.9      31.6          45
# 2018-11-26 17:49:58.107         18.9      31.6          45
# 2018-11-26 17:49:47.846         19.0      31.7          45
# 2018-11-26 17:49:37.601         19.0      31.7          45

# %%
iot.tail()
# Out:
#                          temperature  humidity  luminosity
# date
# 2018-11-14 21:03:28.131         22.0      34.5           0
# 2018-11-14 21:03:17.887         22.1      34.6           0
# 2018-11-14 21:03:07.626         22.1      34.7           0
# 2018-11-14 21:02:57.382         22.1      34.6           0
# 2018-11-14 21:02:47.121         22.1      34.6           0

# %%
iot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 2018-11-26 17:50:18.613 to 2018-11-14 21:02:47.121
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   temperature  100000 non-null  float64
#  1   humidity     100000 non-null  float64
#  2   luminosity   100000 non-null  int64
# dtypes: float64(2), int64(1)
# memory usage: 3.1+ MB

# %%
iot.describe()
# Out:
#          temperature       humidity     luminosity
# count  100000.000000  100000.000000  100000.000000
# mean       20.103505      27.812438      13.341040
# std         1.407949       5.878950      21.749108
# min        17.200000      13.000000       0.000000
# 25%        19.200000      25.000000       0.000000
# 50%        20.000000      27.800000       0.000000
# 75%        21.200000      33.500000      26.000000
# max        23.800000      41.400000      81.000000

# %%
iot.describe().T
# Out:
#                 count       mean        std   min   25%   50%   75%   max
# temperature  100000.0  20.103505   1.407949  17.2  19.2  20.0  21.2  23.8
# humidity     100000.0  27.812438   5.878950  13.0  25.0  27.8  33.5  41.4
# luminosity   100000.0  13.341040  21.749108   0.0   0.0   0.0  26.0  81.0

# %% [markdown]
# #### Sort index by date

# %%
iot_s = iot.sort_index()

# %%
iot_s.head()
# Out:
#                          temperature  humidity  luminosity
# date
# 2018-11-14 21:02:47.121         22.1      34.6           0
# 2018-11-14 21:02:57.382         22.1      34.6           0
# 2018-11-14 21:03:07.626         22.1      34.7           0
# 2018-11-14 21:03:17.887         22.1      34.6           0
# 2018-11-14 21:03:28.131         22.0      34.5           0

# %%
iot_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 2018-11-14 21:02:47.121 to 2018-11-26 17:50:18.613
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   temperature  100000 non-null  float64
#  1   humidity     100000 non-null  float64
#  2   luminosity   100000 non-null  int64
# dtypes: float64(2), int64(1)
# memory usage: 3.1+ MB

# %%
iot_s.plot(figsize=(12,6)) #, rot=90)
# Out:
# <Axes: xlabel='date'>

# %%
# 평균
iot_s.mean()
# Out:
# temperature    20.103505
# humidity       27.812438
# luminosity     13.341040
# dtype: float64

# %%
# 표준편차
iot_s.std()
# Out:
# temperature     1.407949
# humidity        5.878950
# luminosity     21.749108
# dtype: float64

# %% [markdown]
# #### 평균과 표준편차를 이용한 그래프

# %%
iot_s.mean().plot.bar(figsize=(10,5), title="iot data MEAN: temp, humi, lumi")
# Out:
# <Axes: title={'center': 'iot data MEAN: temp, humi, lumi'}>

# %%
iot_s.mean().plot.bar(figsize=(10,5), title="iot data: temp, humi, lumi" , yerr=iot_s.std(), rot=0)
# Out:
# <Axes: title={'center': 'iot data: temp, humi, lumi'}>

# %% [markdown]
# ### 시간 간격에 따른 센서 데이터의 변화 그래프

# %% [markdown]
# ## Plot the change of sensor data over various time spans.
#
# - resample the data at different frequency
# - time span: 60 sec, 1 hour, 1 day, 1 week

# %%
iot_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 2018-11-14 21:02:47.121 to 2018-11-26 17:50:18.613
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   temperature  100000 non-null  float64
#  1   humidity     100000 non-null  float64
#  2   luminosity   100000 non-null  int64
# dtypes: float64(2), int64(1)
# memory usage: 3.1+ MB

# %%
# type of index
iot_s.index[0], type(iot_s.index[0])
# Out:
# ('2018-11-14 21:02:47.121', str)

# %%
# Convert index to timestamp
iot_s.index = pd.to_datetime(iot_s.index)

# %%
iot_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 100000 entries, 2018-11-14 21:02:47.121000 to 2018-11-26 17:50:18.613000
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   temperature  100000 non-null  float64
#  1   humidity     100000 non-null  float64
#  2   luminosity   100000 non-null  int64
# dtypes: float64(2), int64(1)
# memory usage: 3.1 MB

# %% [markdown]
# > 인덱스가 문자열에서 Datatime 인덱스로 전환되었다.
#
# > 시간 지정 및 계산 효과를 그래프에 반영한다.

# %%
# Estimate the mean of iot_s for every 10 minutes
iot_s.resample('600S').mean()  # mean per each 10 minutes
# Out:
#                      temperature   humidity  luminosity
# date
# 2018-11-14 21:00:00    22.086047  34.602326         0.0
# 2018-11-14 21:10:00    22.079310  34.587931         0.0
# 2018-11-14 21:20:00    22.096610  34.594915         0.0
# 2018-11-14 21:30:00    22.086207  34.596552         0.0
# 2018-11-14 21:40:00    22.037288  34.606780         0.0
# ...                          ...        ...         ...
# 2018-11-26 17:10:00    18.925862  31.324138        45.0
# 2018-11-26 17:20:00    18.925424  31.405085        45.0
# 2018-11-26 17:30:00    18.950000  31.505172        45.0
# 2018-11-26 17:40:00    18.957627  31.600000        45.0
# 2018-11-26 17:50:00    18.900000  31.600000        45.0
#
# [1710 rows x 3 columns]

# %%
#  Plot mean of the iot data per every 10 minutes
iot_s.resample('600S').mean().plot(figsize=(12,6), title='10 minutes change of temp, humi, and lumi',
                                ylim=[0,90])
# Out:
# <Axes: title={'center': '10 minutes change of temp, humi, and lumi'}, xlabel='date'>

# %%
# Estimate the mean of iot_s for every hour
iot_s.resample('H').mean()  # mean per each hour
# Out:
#                      temperature   humidity  luminosity
# date
# 2018-11-14 21:00:00    22.063284  34.610448    0.000000
# 2018-11-14 22:00:00    21.998291  34.704274    0.000000
# 2018-11-14 23:00:00    21.918466  34.808807    0.000000
# 2018-11-15 00:00:00    21.848148  34.873219    0.000000
# 2018-11-15 01:00:00    21.799715  34.879772    0.000000
# ...                          ...        ...         ...
# 2018-11-26 13:00:00    18.650712  28.064103   46.051282
# 2018-11-26 14:00:00    18.425641  29.367236   46.000000
# 2018-11-26 15:00:00    18.465242  30.378348   45.837607
# 2018-11-26 16:00:00    18.814530  31.078632   45.330484
# 2018-11-26 17:00:00    18.931525  31.421356   45.000000
#
# [285 rows x 3 columns]

# %%
#  Plot mean of the iot data per every hour
iot_s.resample('H').mean().plot(figsize=(12,6), title='Hourly change of temp, humi, and lumi',
                                ylim=[0,90])
# Out:
# <Axes: title={'center': 'Hourly change of temp, humi, and lumi'}, xlabel='date'>

# %%
# Estimate the mean of iot_s for every day
iot_s.resample('D').mean()  # mean per each day
# Out:
#             temperature   humidity  luminosity
# date
# 2018-11-14    21.992197  34.709441    0.000000
# 2018-11-15    22.323603  34.372125   21.222736
# 2018-11-16    21.920031  36.887350   17.426724
# 2018-11-17    21.571707  34.672015    4.295870
# 2018-11-18    20.475439  30.615840    0.649264
# 2018-11-19    20.035849  26.992477   15.484633
# 2018-11-20    20.226807  25.190281   24.962857
# 2018-11-21    19.926973  25.971556   15.217990
# 2018-11-22    19.902575  21.297330   19.595111
# 2018-11-23    19.486353  18.451288   16.674380
# 2018-11-24    18.597140  22.144554    1.487542
# 2018-11-25    17.937344  27.568850    1.579684
# 2018-11-26    18.088777  29.056529   26.524745

# %%
#  Plot mean of the iot data per every day
iot_s.resample('D').mean().plot(kind='line', marker='o', ms=10, figsize=(12,6), title='Daily change of temperature, humidity, and luminosity')
# Out:
# <Axes: title={'center': 'Daily change of temperature, humidity, and luminosity'}, xlabel='date'>

# %%
#  Plot bar graph using mean of the iot data per every day
iot_s.resample('D').mean().plot(kind='bar', figsize=(12,6), title='Daily change of temperature, humidity, and luminosity')
# Out:
# <Axes: title={'center': 'Daily change of temperature, humidity, and luminosity'}, xlabel='date'>

# %% [markdown]
# #### DIY
# 1. 주별 평균값을 계산하시오.
# 2. 주별 평균값을 시각화 하시오.

# %% [markdown]
# ---

# %%
iot_s.resample('W').mean()
# Out:
#             temperature   humidity  luminosity
# date
# 2018-11-18    21.585195  34.153822   10.572958
# 2018-11-25    19.444706  23.945160   13.571538
# 2018-12-02    18.088777  29.056529   26.524745

# %%
iot_s.resample('W').mean().plot(kind='line', marker='o', ms=10, figsize=(12,6), title='Daily change of temperature, humidity, and luminosity')
# Out:
# <Axes: title={'center': 'Daily change of temperature, humidity, and luminosity'}, xlabel='date'>

# %%
iot_s.resample('W').mean().plot(kind='bar', figsize=(12,6), title='Daily change of temperature, humidity, and luminosity')
# Out:
# <Axes: title={'center': 'Daily change of temperature, humidity, and luminosity'}, xlabel='date'>
